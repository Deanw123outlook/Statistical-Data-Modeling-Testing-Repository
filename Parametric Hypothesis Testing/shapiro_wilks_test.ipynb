# %% [markdown]
# ##### Testing Accuracy of Shapiro - Wilks Test on Randomly Generated Data
# Shapiro Wilks Test tests whether a data sample follows a gauissian distribution (normal distribution)

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2020/04/how-to-generate-random-numbers-in-python/

# %%
#import required libraries
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Randomly generate three lists of data
#Create empty lists
randomlist1, randomlist2, randomlist3 = ([] for i in range(3)) # range() function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and stops before a specified number.

#for loop to append random numbers to empty lists
for i in range(0,100):
    x = random.randint(1,5000)
    randomlist1.append(x)
for i in range(0,100):
    y = random.randint(1,10000)
    randomlist2.append(y)
for i in range(0,100):
    z = random.randint(1,20000)
    randomlist3.append(z)
#Create an array of normaly distributed randome numbers
gauissian = np.random.normal(loc = 0, scale = 1, size = 100)
#Convert np.array to a list
random_normal = gauissian.tolist()

#Convert Lists into a Dictionary
Dictionary = {'X1': randomlist1, 'Y1': randomlist2, 'X2': randomlist3, 'Y2': random_normal }
#Convert Dictionary to pandas dataframe
df = pd.DataFrame(Dictionary)
print(df, df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      100 non-null    int64
#  1   Y1      100 non-null    int64
#  2   X2      100 non-null    int64
#  3   Y2      100 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 3.2 KB
#       X1    Y1     X2        Y2
# 0   4910   144   3293  0.921559
# 1   4891  7912   4735 -0.090059
# 2    738  1105   7048 -0.924070
# 3   4084  3242  12554 -0.598932
# 4   2844   165   2640 -1.264976
# ..   ...   ...    ...       ...
# 95  3871  7294  10207  2.086777
# 96  4706  7644  14335 -0.935022
# 97   386  4486   7827 -2.012760
# 98  2773  4380   4752  0.223779
# 99   974   491   9480  0.554221
#
# [100 rows x 4 columns] None

# %% [markdown]
# ###### Visualizing DIstributions

# %%
#Kernel density plot
sns.distplot(df['X1'], kde = True, hist = False, color = 'b')
sns.set_style('darkgrid')
display(plt.show(), df['X1'].describe())
# Out:
# C:\Users\dwatters\AppData\Local\Temp\ipykernel_8964\1656597999.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['X1'], kde = True, hist = False, color = 'b')
# None
# count     100.000000
# mean     2353.410000
# std      1546.690322
# min        30.000000
# 25%       981.500000
# 50%      2343.500000
# 75%      3871.750000
# max      4910.000000
# Name: X1, dtype: float64

# %%
#Kernel density plot
sns.distplot(df['Y1'], kde = True, hist = False, color = 'b')
sns.set_style('darkgrid')
display(plt.show(), df['Y1'].describe())
# Out:
# C:\Users\dwatters\AppData\Local\Temp\ipykernel_8964\3227709969.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Y1'], kde = True, hist = False, color = 'b')
# None
# count     100.000000
# mean     4825.840000
# std      3079.663371
# min        96.000000
# 25%      2331.250000
# 50%      4536.000000
# 75%      8021.750000
# max      9744.000000
# Name: Y1, dtype: float64

# %%
#Kernel density plot
sns.distplot(df['X2'], kde = True, hist = False, color = 'b')
sns.set_style('darkgrid')
display(plt.show(), df['X2'].describe())
# Out:
# C:\Users\dwatters\AppData\Local\Temp\ipykernel_8964\1198237445.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['X2'], kde = True, hist = False, color = 'b')
# None
# count      100.000000
# mean      9033.390000
# std       5373.550723
# min        102.000000
# 25%       4724.750000
# 50%       8341.500000
# 75%      12964.000000
# max      19693.000000
# Name: X2, dtype: float64

# %%
#Kernel density plot
sns.distplot(df['Y2'], kde = True, hist = False, color = 'r')
sns.set_style('darkgrid')
display(plt.show(), df['Y2'].describe())
# Out:
# C:\Users\dwatters\AppData\Local\Temp\ipykernel_8964\3845287750.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Y2'], kde = True, hist = False, color = 'r')
# None
# count    100.000000
# mean      -0.284763
# std        1.143360
# min       -2.605367
# 25%       -1.066441
# 50%       -0.352824
# 75%        0.419427
# max        2.712819
# Name: Y2, dtype: float64

# %% [markdown]
# As we can see from the above kernel density plot visualizations three out four features follow a gaussian distribution.

# %% [markdown]
# ##### Shapiro-Wilk Test
# This statistical test will test whether a data sample has a Gaussian distribution.
#
# Assumptions:
#
# Observations in each sample are independent and identically distributed
#
# Interpretation:
#
# H0: the sample has a Gaussian distribution.
#
# H1: the sample does not have a Gaussian distribution.

# %%
#Interpretation
#H0: the sample has a Gaussian distribution.
#H1: the sample does not have a Gaussian distribution.
from scipy.stats import shapiro
test_1 = df['X1']
stat, p = shapiro(test_1)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('X1 variable probable to follow a Gaussian Distribution')
else:
    print('X1 variable probable not to follow a Gaussian Distribution')
# Out:
# stat=0.932, p=0.000
# X1 variable probable not to follow a Gaussian Distribution

# %%
from scipy.stats import shapiro
test_1 = df['Y1']
stat, p = shapiro(test_1)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Y1 variable probable to follow a Gaussian Distribution')
else:
    print('Y1 variable probable not to follow a Gaussian Distribution')
# Out:
# stat=0.923, p=0.000
# Y1 variable probable not to follow a Gaussian Distribution

# %%
from scipy.stats import shapiro
test_1 = df['X2']
stat, p = shapiro(test_1)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('X2 variable probable to follow a Gaussian Distribution')
else:
    print('X2 variable probable not to follow a Gaussian Distribution')
# Out:
# stat=0.962, p=0.006
# X2 variable probable not to follow a Gaussian Distribution

# %%
from scipy.stats import shapiro
test_1 = df['Y2']
stat, p = shapiro(test_1)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Y2 variable probable to follow a Gaussian Distribution')
else:
    print('Y2 variable probable not to follow a Gaussian Distribution')
# Out:
# stat=0.987, p=0.407
# Y2 variable probable to follow a Gaussian Distribution

# %% [markdown]
# We can confirm that the testing envoirnment has been succesful in determining accurately whether individual data features follow a gaussian distribution.
